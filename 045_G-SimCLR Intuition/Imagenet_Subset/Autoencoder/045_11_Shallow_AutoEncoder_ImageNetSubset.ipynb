# %% [markdown]
# # Motivation
# The motivation behind this notebook is to build a `denoising autoencoder`. The following things are to be kept in mind.
# 1. Dataset used is `ImageNet Subset`.
# 2. The t-SNE of the embeddings are analysed.
# 3. The latent space is clustered into `64 clusters`. (equisized would be great)

# %% [markdown]
# # Imports
# The packages used are:
# 1. tensorflow
# 2. `tf.keras`
# 3. numpy
# 4. matplotlip
# 5. sklearn
# 6. scipy
# 7. random
# 8. imutils
# 9. tqdm

# %%
! nvidia-smi
# Out:
# Fri Oct  2 07:09:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %%capture
! pip install wandb
import wandb
from wandb.keras import WandbCallback

# %%
! wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
wandb.init(entity="g-simclr", project="g-simclr", id="imgNet-subset-autoenc-shallow")

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib
from matplotlib import pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.model_selection import train_test_split

from scipy.special import comb

import random
from imutils import paths
from tqdm import tqdm

# %% [markdown]
# # Dataset gathering and preparation
# * Using `ImageNetSubset` which consists of 5 categories.
# * Builing a `tf.data.Dataset` of the images.
# * We need to pre-process the data before loading.
#
# The dataset comes in the train and test folders. For the autoencoder we are going use the `train` only and keep the `test` folder as in to prevent data leakage in the further evaluation steps.

# %%
# Gather dataset
# !git clone https://github.com/thunderInfy/imagenet-5-categories
# Out:
# Cloning into 'imagenet-5-categories'...
# remote: Enumerating objects: 1532, done.
# remote: Total 1532 (delta 0), reused 0 (delta 0), pack-reused 1532
# Receiving objects: 100% (1532/1532), 88.56 MiB | 50.10 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# Train image paths
train_images = list(paths.list_images("imagenet-5-categories/train"))
print('Info: # of train images: {}'.format(len(train_images)))

# Test image paths
test_images = list(paths.list_images("imagenet-5-categories/test"))
print('Info: # of test images: {}'.format(len(test_images)))
# Out:
# Info: # of train images: 1250
# Info: # of test images: 250

# %%
# Image preprocessing utils
@tf.function
def parse_images(image_path):
    image_string = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(image_string, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size=[224, 224])

    return image, image

# %%
# Create TensorFlow dataset.
BATCH_SIZE = 64

train_ds = tf.data.Dataset.from_tensor_slices(train_images)
train_ds = (
    train_ds
    .map(parse_images, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .cache()
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

test_ds = tf.data.Dataset.from_tensor_slices(test_images)
test_ds = (
    test_ds
    .map(parse_images, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .cache()
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %% [markdown]
# ## Autoencoder Shallow

# %%
def make_autoencoder(inputs):
  # 224,224,3
  x = tf.keras.layers.GaussianNoise(stddev=1e-2)(inputs)
  x = tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  x = tf.keras.layers.MaxPool2D()(x)
  # 112,112,32
  x = tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  x = tf.keras.layers.MaxPool2D()(x)
  # 56,56,64
  x = tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  x = tf.keras.layers.MaxPool2D(name='retrieval')(x)
  # 28,28,128
  x = tf.keras.layers.UpSampling2D()(x)
  # 56,56,128
  x = tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  x = tf.keras.layers.UpSampling2D()(x)
  # 112,112,128
  x = tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  x = tf.keras.layers.UpSampling2D()(x)
  # 224,224,64
  x = tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.ReLU()(x)
  # 224,224,64
  x = tf.keras.layers.Conv2D(filters=3,kernel_size=(3,3),activation='sigmoid',padding='same', name='auto_output')(x)

  return x

# %% [markdown]
# ## Training

# %%
# # Relu
# relu_variation = tf.keras.layers.ReLU(threshold=25/65025.)
# def my_loss(y_true, y_pred):
#   # (N, H,W,C)
#   squared_diff = tf.math.square(y_true - y_pred)
#   squared_diff_relu = relu_variation(squared_diff)
#   app_exact_match = tf.math.reduce_mean(squared_diff_relu, axis=-1)
#   return app_exact_match

# %%
tf.keras.backend.clear_session()

inputs = tf.keras.Input(shape=(224,224,3))
outputs = make_autoencoder(inputs)

model = tf.keras.Model(
		inputs=inputs,
		outputs=outputs,
		name="autoencoder"
		)
optimizer = keras.optimizers.Adam(lr=1e-4)
model.compile(optimizer=optimizer,loss='mse')
model.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 32)      128
# _________________________________________________________________
# re_lu (ReLU)                 (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 56, 56, 128)       0
# _________________________________________________________________
# retrieval (MaxPooling2D)     (None, 28, 28, 128)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 56, 56, 128)       0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 112, 112, 128)     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 112, 112, 64)      73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 112, 112, 64)      0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 224, 224, 32)      18464
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 224, 224, 32)      0
# _________________________________________________________________
# auto_output (Conv2D)         (None, 224, 224, 3)       867
# =================================================================
# Total params: 335,747
# Trainable params: 334,851
# Non-trainable params: 896
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, verbose=2, restore_best_weights=True)

# %%
history = model.fit(
    train_ds,
    validation_data = test_ds,
    epochs=100,
    callbacks=[es, WandbCallback()]
    )
# Out:
# Epoch 1/100
# 19/19 [==============================] - 10s 522ms/step - loss: 0.0565 - val_loss: 0.0690
# Epoch 2/100
# 19/19 [==============================] - 10s 523ms/step - loss: 0.0244 - val_loss: 0.0616
# Epoch 3/100
# 19/19 [==============================] - 10s 530ms/step - loss: 0.0170 - val_loss: 0.0588
# Epoch 4/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0139 - val_loss: 0.0573
# Epoch 5/100
# 19/19 [==============================] - 10s 539ms/step - loss: 0.0123 - val_loss: 0.0547
# Epoch 6/100
# 19/19 [==============================] - 10s 543ms/step - loss: 0.0113 - val_loss: 0.0515
# Epoch 7/100
# 19/19 [==============================] - 10s 544ms/step - loss: 0.0107 - val_loss: 0.0484
# Epoch 8/100
# 19/19 [==============================] - 10s 543ms/step - loss: 0.0102 - val_loss: 0.0455
# Epoch 9/100
# 19/19 [==============================] - 10s 538ms/step - loss: 0.0098 - val_loss: 0.0427
# Epoch 10/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0095 - val_loss: 0.0400
# Epoch 11/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.0093 - val_loss: 0.0373
# Epoch 12/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.0091 - val_loss: 0.0344
# Epoch 13/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.0089 - val_loss: 0.0315
# Epoch 14/100
# 19/19 [==============================] - 10s 539ms/step - loss: 0.0087 - val_loss: 0.0286
# Epoch 15/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0086 - val_loss: 0.0257
# Epoch 16/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0084 - val_loss: 0.0230
# Epoch 17/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0083 - val_loss: 0.0204
# Epoch 18/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0082 - val_loss: 0.0179
# Epoch 19/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0081 - val_loss: 0.0158
# Epoch 20/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0080 - val_loss: 0.0139
# Epoch 21/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0079 - val_loss: 0.0124
# Epoch 22/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0078 - val_loss: 0.0111
# Epoch 23/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0077 - val_loss: 0.0101
# Epoch 24/100
# 19/19 [==============================] - 10s 524ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 25/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.0075 - val_loss: 0.0087
# Epoch 26/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0075 - val_loss: 0.0083
# Epoch 27/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 28/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 29/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0073 - val_loss: 0.0075
# Epoch 30/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 31/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 32/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 33/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 34/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 35/100
# 19/19 [==============================] - 10s 524ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 36/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 37/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 38/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 39/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 40/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 41/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 42/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 43/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 44/100
# 19/19 [==============================] - 10s 529ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 45/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 46/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 47/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 48/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 49/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 50/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 51/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 52/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 53/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 54/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 55/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 56/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 57/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 58/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 59/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 60/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 61/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 62/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 63/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 64/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 65/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 66/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 67/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 68/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 69/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 70/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 71/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 72/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 73/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 74/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 75/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 76/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 77/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 78/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 79/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 80/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 81/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 82/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 83/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 84/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 85/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 86/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 87/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 88/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 89/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 90/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 91/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 92/100
# 19/19 [==============================] - 10s 524ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 93/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 94/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 95/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 96/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 97/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 98/100
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 99/100
# 19/19 [==============================] - 10s 527ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 100/100
# 19/19 [==============================] - 10s 526ms/step - loss: 0.0053 - val_loss: 0.0050

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
loss = model.evaluate(test_ds)
print('INFO: loss on test: {:.4f}'.format(loss))
# Out:
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0048WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0330s vs `on_test_batch_end` time: 0.1376s). Check your callbacks.
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0049
# INFO: loss on test: 0.0049

# %% [markdown]
# ### Store the model

# %%
from google.colab import drive
import datetime
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Colab Notebooks/Souradip Sayak/SimCLR_PseudoLabels/Models/'

# %%
filename = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "shallow_autoencoder_imagenet.h5"
filename = path+filename
filename
# Out:
# '/content/drive/My Drive/Colab Notebooks/Souradip Sayak/SimCLR_PseudoLabels/Models/20200820-104631shallow_autoencoder_imagenet.h5'

# %%
model.save(filename)

# %% [markdown]
# ## Evaluation
# Let's see the reconstruction the model provides on the unseen test-set

# %%
import cv2

# %%
def prepare_images(image_paths):
    images = []
    labels = []

    for image in tqdm(image_paths):
        image_pixels = plt.imread(image)
        image_pixels = cv2.resize(image_pixels, (224, 224))
        image_pixels = image_pixels/255.

        label = image.split("/")[2].split("_")[0]

        images.append(image_pixels)
        labels.append(label)

    images = np.array(images)
    labels = np.array(labels)

    print(images.shape, labels.shape)

    return images, labels

# %%
X_train, y_train = prepare_images(train_images)
X_test, y_test = prepare_images(test_images)
print('INFO: X_train: {}'.format(X_train.shape))
print('INFO: y_train: {}'.format(y_train.shape))
print('INFO: X_test: {}'.format(X_test.shape))
print('INFO: y_test: {}'.format(y_test.shape))
# Out:
# 100%|██████████| 1250/1250 [00:05<00:00, 210.65it/s]
#   6%|▌         | 14/250 [00:00<00:01, 136.38it/s]
# (1250, 224, 224, 3) (1250,)
# 100%|██████████| 250/250 [00:01<00:00, 222.31it/s]
# (250, 224, 224, 3) (250,)
# INFO: X_train: (1250, 224, 224, 3)
# INFO: y_train: (1250,)
# INFO: X_test: (250, 224, 224, 3)
# INFO: y_test: (250,)

# %%
# Taking 5 images from the test dataset for reconstruction
img = X_test[:5].copy()
rec = model.predict(img)
img.shape, rec.shape
# Out:
# ((5, 224, 224, 3), (5, 224, 224, 3))

# %%
plt.figure(figsize=(20, 4))
print("Test Images")
for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.imshow(img[i])
plt.show() 

plt.figure(figsize=(20, 4))
print("Reconstruction of Test Images")
for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.imshow(rec[i])
plt.show()
# Out:
# Test Images
# Reconstruction of Test Images

# %% [markdown]
# # Retrieval
# This section of the code extracts the embeddings. The embeddings are later used to cluster together to present the t-SNE. The

# %%
layer_name = 'retrieval'
slice_model = tf.keras.Model(
    inputs=model.input,
    outputs=model.get_layer(layer_name).output
    )
slice_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 32)      128
# _________________________________________________________________
# re_lu (ReLU)                 (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 56, 56, 128)       0
# _________________________________________________________________
# retrieval (MaxPooling2D)     (None, 28, 28, 128)       0
# =================================================================
# Total params: 94,144
# Trainable params: 93,696
# Non-trainable params: 448
# _________________________________________________________________

# %%
latent_train = slice_model.predict(X_train)
latent_test = slice_model.predict(X_test)
latent_train.shape, latent_test.shape
# Out:
# ((1250, 28, 28, 128), (250, 28, 28, 128))

# %%
embedding_train = tf.keras.layers.GlobalAveragePooling2D()(latent_train)
embedding_test = tf.keras.layers.GlobalAveragePooling2D()(latent_test)
embedding_train.shape, embedding_test.shape
# Out:
# (TensorShape([1250, 128]), TensorShape([250, 128]))

# %% [markdown]
# ## t-SNE of the latent space
# Here we observe the embeddings. This would be a good place to see what is happening in the autoencoder. This would also provide us with the intuitions of clusters.

# %%
tsne_train = TSNE(n_components=2).fit_transform(embedding_train)
tsne_test = TSNE(n_components=2).fit_transform(embedding_test)
tsne_train.shape, tsne_test.shape
# Out:
# ((1250, 2), (250, 2))

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %%
colors = ['red','green','blue','purple','cyan']
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(tsne_train[:,0],tsne_train[:,1],c=y_train_enc, cmap=matplotlib.colors.ListedColormap(colors))
plt.title('Train')
plt.subplot(1,2,2)
plt.scatter(tsne_test[:,0],tsne_test[:,1],c=y_test_enc, cmap=matplotlib.colors.ListedColormap(colors))
plt.title('Test')
plt.show()

# %% [markdown]
# ## Cluster the train latent

# %%
BATCH_SIZE = 64
classifier = KMeans(n_clusters=BATCH_SIZE, random_state=0).fit(embedding_train)
# labels of the clusters
labels = classifier.labels_
labels.shape
# Out:
# (1250,)

# %% [markdown]
# ## Ordering the data

# %%
import pandas as pd

# %%
# Building the DataFrame
df = pd.DataFrame()
df['cluster_labels'] = labels
df['imag_ind'] = np.arange(0,len(df))
df = df[['imag_ind','cluster_labels']]
df.head()
# Out:
#    imag_ind  cluster_labels
# 0         0              18
# 1         1              62
# 2         2              62
# 3         3               7
# 4         4               4

# %%
# The rank according to the cluster_labels
df["rank"] = df.groupby("cluster_labels")["imag_ind"].rank("dense", ascending=True)
df.head()
# Out:
#    imag_ind  cluster_labels  rank
# 0         0              18   1.0
# 1         1              62   1.0
# 2         2              62   2.0
# 3         3               7   1.0
# 4         4               4   1.0

# %%
# Sorting the labels by cluster_labels and rank
df_data = df.sort_values(by = ['cluster_labels','rank'])
df_data.head()
# Out:
#      imag_ind  cluster_labels  rank
# 46         46               0   1.0
# 57         57               0   2.0
# 76         76               0   3.0
# 149       149               0   4.0
# 155       155               0   5.0

# %%
# Sort with respect to rank only
df_data2 = df_data.sort_values(by = ['rank'])
df_data2.head()
# Out:
#      imag_ind  cluster_labels  rank
# 46         46               0   1.0
# 73         73               8   1.0
# 30         30              53   1.0
# 220       220              35   1.0
# 116       116              54   1.0

# %%
arr_ind = df_data2['imag_ind'].values
X_new = X_train[arr_ind]

# %%
X_new.shape
# Out:
# (1250, 224, 224, 3)

# %%
path = '/content/drive/My Drive/Colab Notebooks/Souradip Sayak/SimCLR_PseudoLabels/Data/'

# %%
data_path = path+'X_new_shallow.npy'
with open(data_path, 'wb') as f:
  np.save(f, X_new)
