# %%
from WOA import BaseWOA, BaoWOA
from functions import *

# %%
## Setting parameters`
root_paras = {
    "problem_size": 100,
    "domain_range": [-100, 100],
    "print_train": True,
    "objective_func": C30
}
woa_paras = {
    "epoch": 1000,
    "pop_size": 100
}

# %%
## Run model
md = BaoWOA(root_algo_paras=root_paras, woa_paras=woa_paras)
md._train__()
# Out:
# Epoch = 1, Fit = 3530409003100398.5
# Epoch = 2, Fit = 1413876463105914.2
# Epoch = 3, Fit = 102129821994501.52
# Epoch = 4, Fit = 71591683059450.92
# Epoch = 5, Fit = 37230270267072.88
# Epoch = 6, Fit = 21339616372067.266
# Epoch = 7, Fit = 1571503797615.1953
# Epoch = 8, Fit = 347719246311.1837
# Epoch = 9, Fit = 11194245662.663761
# Epoch = 10, Fit = 7566977.081782416
# Epoch = 11, Fit = 578956.3251046923
# Epoch = 12, Fit = 383566.4074511529
# Epoch = 13, Fit = 289118.9172110375
# Epoch = 14, Fit = 134880.59234874518
# Epoch = 15, Fit = 130909.70779836594
# Epoch = 16, Fit = 52087.966840354355
# Epoch = 17, Fit = 13288.861590136386
# Epoch = 18, Fit = 11715.873029105333
# Epoch = 19, Fit = 11677.923948004203
# Epoch = 20, Fit = 11395.588160213136
# Epoch = 21, Fit = 10894.312224731162
# Epoch = 22, Fit = 10765.48142229608
# Epoch = 23, Fit = 10699.430024229558
# Epoch = 24, Fit = 10620.543956536148
# Epoch = 25, Fit = 10607.784267266627
# Epoch = 26, Fit = 10603.16095403249
# ...
