# %%
from QSO import LevyOppQSO
from functions import *

# %%
## Setting parameters
root_paras = {
    "problem_size": 100,
    "domain_range": [-100, 100],
    "print_train": True,
    "objective_func": C1
}
qso_paras = {
    "epoch": 1000,
    "pop_size": 100,
}

## Run model
md = LevyOppQSO(root_algo_paras=root_paras, qso_paras=qso_paras)
md._train__()
# Out:
# best fit  238375847.6525817  in gen  0
# best fit  6745947.15401497  in gen  1
# best fit  6745947.15401497  in gen  2
# best fit  6745947.15401497  in gen  3
# best fit  3855811.70844864  in gen  4
# best fit  3077068.717907814  in gen  5
# best fit  3077068.717907814  in gen  6
# best fit  2802275.467126569  in gen  7
# best fit  2610202.893751463  in gen  8
# best fit  2457890.968980571  in gen  9
# best fit  2329205.6415242273  in gen  10
# best fit  2257158.6882266714  in gen  11
# best fit  2028560.6037865663  in gen  12
# best fit  1761231.2277795593  in gen  13
# best fit  1499599.2074442708  in gen  14
# best fit  1317278.7863587392  in gen  15
# best fit  1271682.273312939  in gen  16
# best fit  1168285.5717496844  in gen  17
# best fit  1078512.7076711962  in gen  18
# best fit  1076594.7982911987  in gen  19
# best fit  991899.6262062567  in gen  20
# best fit  920409.7685872293  in gen  21
# best fit  886482.2738008507  in gen  22
# ...
