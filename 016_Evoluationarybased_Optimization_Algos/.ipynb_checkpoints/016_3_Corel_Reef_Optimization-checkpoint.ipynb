# %%
from CRO import BaseCRO
from functions import *

# %%
## Setting parameters
root_paras = {
    "problem_size": 100,
    "domain_range": [-100, 100],
    "print_train": True,
    "objective_func": C30
}

cro_paras = {
    "epoch": 1000,
    "pop_size": 100,
    "G": [0.02, 0.2],
    "GCR": 0.1,
    "po": 0.4,
    "Fb": 0.9,
    "Fa": 0.1,
    "Fd": 0.1,
    "Pd": 0.1,
    "k": 3
}

## Run model
md = BaseCRO(root_algo_paras=root_paras, cro_paras=cro_paras)
md._train__()
# Out:
# > Epoch 1: Best training fitness 1000000
# > Epoch 2: Best training fitness 1000000
# > Epoch 3: Best training fitness 1000000
# > Epoch 4: Best training fitness 1000000
# > Epoch 5: Best training fitness 1000000
# > Epoch 6: Best training fitness 1000000
# > Epoch 7: Best training fitness 1000000
# > Epoch 8: Best training fitness 1000000
# > Epoch 9: Best training fitness 1000000
# > Epoch 10: Best training fitness 1000000
# > Epoch 11: Best training fitness 1000000
# > Epoch 12: Best training fitness 1000000
# > Epoch 13: Best training fitness 1000000
# > Epoch 14: Best training fitness 1000000
# > Epoch 15: Best training fitness 1000000
# > Epoch 16: Best training fitness 1000000
# > Epoch 17: Best training fitness 1000000
# > Epoch 18: Best training fitness 1000000
# > Epoch 19: Best training fitness 1000000
# > Epoch 20: Best training fitness 1000000
# > Epoch 21: Best training fitness 1000000
# > Epoch 22: Best training fitness 1000000
# ...
