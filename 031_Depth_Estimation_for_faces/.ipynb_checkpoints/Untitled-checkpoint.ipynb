# %%
import cv2 
cv2.dnn.writeTextGraph('FrozenMaster.pb', 'graph.pbtxt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-56f192cc9960> in <module>
#       1 import cv2
# ----> 2 cv2.dnn.writeTextGraph('FrozenMaster.pb', 'graph.pbtxt')
#
# AttributeError: module 'cv2.dnn' has no attribute 'writeTextGraph'
