# %%
from NRO import BaseNRO
from functions import *

# %%
## Setting parameters
root_paras = {
    "problem_size": 100,
    "domain_range": [-100, 100],
    "print_train": True,
    "objective_func": C30
}
nro_paras = {
    "epoch": 1000,
    "pop_size": 100
}

## Run model
md = BaseNRO(root_algo_paras=root_paras, nro_paras=nro_paras)
md._train__()
# Out:
# Generation : 1, best result so far: 1477170092334103.5
# F:\100daysofML\014_TOW_and_NRO_Algo\NRO.py:42: RuntimeWarning: invalid value encountered in sqrt
#   levy_b = (np.random.normal(0, xichma_u ** 2)) / (np.sqrt(np.random.normal(0, xichma_v ** 2)) ** (1.0 / 1.5))
# Generation : 2, best result so far: 779192143390853.1
# Generation : 3, best result so far: 445540622361667.06
# Generation : 4, best result so far: 47559934130203.164
# Generation : 5, best result so far: 45622769971530.84
# Generation : 6, best result so far: 45622769971530.84
# Generation : 7, best result so far: 45622769971530.84
# Generation : 8, best result so far: 38834884400865.19
# Generation : 9, best result so far: 20254840473792.242
# Generation : 10, best result so far: 20254840473792.242
# Generation : 11, best result so far: 7966952199969.136
# Generation : 12, best result so far: 7966952199969.136
# Generation : 13, best result so far: 7966952199969.136
# ...
